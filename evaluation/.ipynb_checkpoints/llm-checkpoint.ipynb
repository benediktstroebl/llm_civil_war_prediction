# %% [markdown]
# ### LLM predicting conflicts

# %%
import os
os.environ["OPENAI_API_KEY"] = ""  # TODO: add API key
from openai import OpenAI
client = OpenAI()

import pandas as pd
import numpy as np
import random
import time
from tqdm.notebook import tqdm
import pickle
import matplotlib.pyplot as plt

def call_gpt(
    prompt, temperature, max_length, model, stop=["\n"]
):
    while 1:
        try:
            response = client.chat.completions.create(
                model=model,
                messages=[
                    {
                        "role": "system",
                        "content": 'You are a helpful Assistant, and you only response to the "Assistant". Remember, maintain a natural tone. Be precise, concise, and casual. Keep it short.',
                    },
                    {"role": "user", "content": prompt},
                ],
                temperature=temperature,
                max_tokens=max_length,
                stop=stop,
            )
            break
        except:
            print("Openai API error, sleep for 1s")
            time.sleep(1)
    return [response.choices[0].message.content.strip()]

# %% [markdown]
# #### Load data from paper

# %%
# Get features from dta file
feature_data_path = "../data/Replication/estimationdata_withlags.dta"
feature_data = pd.read_stata(feature_data_path)
# print(feature_data)

# %%
# Get all countries
countries = feature_data["statename"].unique()
country_codes = {}
for country in countries:
    country_codes[country] = feature_data[feature_data["statename"] == country]["gwno"].unique()[0]
# print(country_codes, len(countries))

# %% [markdown]
# #### Different models in the paper use different features (using model m23 for now)
#
# from ../data/Replication/estimationreplication.do, the script for running simulation in the paper, where the variables used in each model is defined. Skip variables that are a function of history data, since the information is available in the context
#
#
# /*Model m23*/
# mlogit conflict lc1 lc2 ltsc0 ltsc1 ltsc2 loi loic1 loic2 lois0 let letc1 letc2 lets0 lli limc1 limc2 lims0 lyo lyoc1 lyoc2 lyos0 llpo lpoc1 lpoc2 lpos0 led ledc1 ledc2 leds0 llin ledn lyon lnc1 lnc1c1 lnc1c2 lnc1ts0 r4 r6 r7 if year >= 1970 & year <= 2009,baseoutcome(0) cons(103/112 115/156 99/100)
# variable_names = ['lc1', 'lc2', 'ltsc0', 'ltsc1', 'ltsc2', 'loi', 'loic1', 'loic2', 'lois0', 'let', 'letc1', 'letc2', 'lets0', 'lli', 'limc1', 'limc2', 'lims0', 'lyo', 'lyoc1', 'lyoc2', 'lyos0', 'llpo', 'lpoc1', 'lpoc2', 'lpos0', 'led', 'ledc1', 'ledc2', 'leds0', 'llin', 'ledn', 'lyon', 'lnc1', 'lnc1c1', 'lnc1c2', 'lnc1ts0', 'r4', 'r6', 'r7']
# variable_names = ['llpo', 'lnc1', 'lnc1c1', 'lnc1c2', 'lnc1ts0', 'r4', 'r6', 'r7']
# for i, name in enumerate(variable_names):
#     print(_MAP_CSV_NAME_TO_VARIABLE_ENUM_FOR_STATS_BASE[name])

# %%
# convert the data in those variables from year 1970 to 2009 for a country to a string
country_pred = 'Liberia'
his_start_year = 1991
his_end_year = 2000
pred_start_year = 2001
pred_end_year = 2019
variable_names = ['llpo', 'lnc1', 'lnc1c1', 'lnc1c2', 'lnc1ts0', 'r4', 'r6', 'r7']  # for m23

def get_example(country, start_year, end_year):
    full_str = ''
    for i in range(start_year, end_year):
        full_str += f'Year {i}:'
        
        # check if the year exists for this country
        if len(feature_data.loc[(feature_data['year'] == i) & (feature_data['statename'] == country)]) == 0:
            full_str += ' No data\n'
            continue

        for name in variable_names:
            value = feature_data.loc[(feature_data['year'] == i) & (feature_data['statename'] == country)][name].values[0]
            if name in ['r4', 'r6', 'r7']:
                value = int(value)
                full_str += f' {name} {value}'
            else:
                full_str += f' {name} {value:.2f}'
            
        # add conflict
        conflict = int(feature_data.loc[(feature_data['year'] == i) & (feature_data['statename'] == country)]["conflict"].values[0])
        full_str += f' conflict {conflict}'
        full_str += '\n'
    return full_str
example = get_example(country_pred, his_start_year, his_end_year)
print(country_pred, '\n', example)
# Out:
# Liberia
#  Year 1991: llpo 7.67 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1992: llpo 7.65 lnc1 1.00 lnc1c1 0.00 lnc1c2 1.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 2
# Year 1993: llpo 7.64 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1994: llpo 7.63 lnc1 1.00 lnc1c1 0.00 lnc1c2 1.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1995: llpo 7.64 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1996: llpo 7.67 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1997: llpo 7.73 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1998: llpo 7.81 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1999: llpo 7.90 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.39 r4 0 r6 1 r7 0 conflict 0

# %%
def get_pred(country_pred, 
             his_start_year, 
             his_end_year, 
             pred_start_year,
             pred_end_year,
             use_cot=True,
             num_example=10,
             num_pred=1, 
             pred_T=0,
             max_pred_len=1024, # with CoT
             model="gpt-4-0125-preview",
             dummy=False,
    ):
    max_example = 2*num_example
    country_examples = random.sample(countries.tolist(), max_example)
    examples = []
    for country in country_examples:
        # try:    # sometimes some country miss data in some year
        example = get_example(country, his_start_year, his_end_year)
        examples.append(example)
        if len(examples) == num_example: break
        # except:
        #     print('Skip country:', country)
        #     continue

    prompt_bg = f"""
    You are going to predict the conflict level (no, minor, major) of a country from year {pred_start_year} to {pred_end_year}. You are given the history data from {his_start_year} to {his_end_year} for the country, as well as data from a few other countries. For each year, you are given the following features:

    - `llpo`: current_population_level
    - `lnc1`: previous_neighborhood_has_conflict
    - `lnc1c1`: previous_neighborhood_has_conflict_times_previous_year_was_minor
    - `lnc1c2`: previous_neighborhood_has_conflict_times_previous_year_was_major
    - `lnc1ts0`: previous_neighborhood_has_conflict_times_previous_logs_no_conflict
    - `r4`: country_in_west_asia_north_africa_region
    - `r6`: country_in_west_africa_region
    - `r7`: country_in_south_africa_region

    These are the examples:
    """.strip()
    prompt = prompt_bg
    for example in examples:
        prompt += f"\nCountry ?\n{example}"

    # add country to predict
    prompt += f"\nNow, this is the history data for the country you are going to predict:\n{get_example(country_pred, his_start_year, his_end_year)}"
    if use_cot:
        prompt += f'\nCarefully reason the relationship between the features and the conflict level, and then output:\n1. Your reasoning in about 3-5 sentences\n2. Your prediction with the format "Year [year]: [0/1/2]", for year from {pred_start_year} to {pred_end_year}.'
    else:
        prompt += f'\nOutput your prediction with the format "Year [year]: [0/1/2]", for year from {pred_start_year} to {pred_end_year}. Do not include reasoning.'
    print(prompt)

    # get pred
    preds = []
    for _ in range(num_pred):
        if dummy:
            pred = [0 for _ in range(pred_end_year - pred_start_year + 1)]
        else:
            pred = call_gpt(prompt, 
                            temperature=pred_T, 
                            max_length=max_pred_len, 
                            model=model,
                            stop=None)[0]
        preds.append(pred)
    return preds

def extract_pred(output, start_year, end_year):
    """Get numbers from GPT output"""
    preds = []
    for i in range(start_year, end_year+1):
        pred = output.split(f"Year {i}:")[1].strip()[0]
        preds.append(int(pred))
    return preds

# %%
# test the prompt and CoT
raw_pred = get_pred(country_pred, 
                    his_start_year, 
                    his_end_year, 
                    pred_start_year,
                    pred_end_year,
                    use_cot=True,
                    dummy=False,
                    )[0]
print(raw_pred)
# Out:
# You are going to predict the conflict level (no, minor, major) of a country from year 2001 to 2019. You are given the history data from 1991 to 2000 for the country, as well as data from a few other countries. For each year, you are given the following features:
#
#     - `llpo`: current_population_level
#     - `lnc1`: previous_neighborhood_has_conflict
#     - `lnc1c1`: previous_neighborhood_has_conflict_times_previous_year_was_minor
#     - `lnc1c2`: previous_neighborhood_has_conflict_times_previous_year_was_major
#     - `lnc1ts0`: previous_neighborhood_has_conflict_times_previous_logs_no_conflict
#     - `r4`: country_in_west_asia_north_africa_region
#     - `r6`: country_in_west_africa_region
#     - `r7`: country_in_south_africa_region
#
#     These are the examples:
# Country ?
# Year 1991: llpo 8.81 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.18 r4 0 r6 0 r7 0 conflict 0
# Year 1992: llpo 8.83 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.27 r4 0 r6 0 r7 0 conflict 0
# Year 1993: llpo 8.85 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.36 r4 0 r6 0 r7 0 conflict 0
# Year 1994: llpo 8.87 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.44 r4 0 r6 0 r7 0 conflict 0
# Year 1995: llpo 8.90 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.26 r4 0 r6 0 r7 0 conflict 0
# Year 1996: llpo 8.92 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.30 r4 0 r6 0 r7 0 conflict 0
# Year 1997: llpo 8.94 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.33 r4 0 r6 0 r7 0 conflict 0
# Year 1998: llpo 8.96 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.37 r4 0 r6 0 r7 0 conflict 0
# Year 1999: llpo 8.98 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.40 r4 0 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 8.33 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1992: llpo 8.35 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1993: llpo 8.38 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.69 r4 0 r6 0 r7 0 conflict 0
# Year 1994: llpo 8.40 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.10 r4 0 r6 0 r7 0 conflict 0
# Year 1995: llpo 8.43 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.39 r4 0 r6 0 r7 0 conflict 0
# Year 1996: llpo 8.45 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.61 r4 0 r6 0 r7 0 conflict 0
# Year 1997: llpo 8.47 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.79 r4 0 r6 0 r7 0 conflict 0
# Year 1998: llpo 8.49 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.95 r4 0 r6 0 r7 0 conflict 0
# Year 1999: llpo 8.51 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 2.08 r4 0 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 11.46 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 5.89 r4 0 r6 1 r7 0 conflict 0
# Year 1992: llpo 11.49 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.00 r4 0 r6 1 r7 0 conflict 0
# Year 1993: llpo 11.51 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.04 r4 0 r6 1 r7 0 conflict 0
# Year 1994: llpo 11.54 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.09 r4 0 r6 1 r7 0 conflict 0
# Year 1995: llpo 11.57 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.14 r4 0 r6 1 r7 0 conflict 0
# Year 1996: llpo 11.60 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1997: llpo 11.63 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.22 r4 0 r6 1 r7 0 conflict 0
# Year 1998: llpo 11.65 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.26 r4 0 r6 1 r7 0 conflict 0
# Year 1999: llpo 11.68 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.30 r4 0 r6 1 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo nan lnc1 nan lnc1c1 nan lnc1c2 nan lnc1ts0 nan r4 1 r6 0 r7 0 conflict 0
# Year 1992: llpo 7.35 lnc1 1.00 lnc1c1 nan lnc1c2 nan lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0
# Year 1993: llpo 7.33 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0
# Year 1994: llpo 7.31 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.69 r4 1 r6 0 r7 0 conflict 0
# Year 1995: llpo 7.29 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.10 r4 1 r6 0 r7 0 conflict 0
# Year 1996: llpo 7.27 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 2.77 r4 1 r6 0 r7 0 conflict 0
# Year 1997: llpo 7.26 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.22 r4 1 r6 0 r7 0 conflict 0
# Year 1998: llpo 7.25 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0
# Year 1999: llpo 7.24 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 9.09 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1992: llpo 9.12 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1993: llpo 9.14 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1994: llpo 9.16 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1995: llpo 9.19 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1996: llpo 9.21 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1997: llpo 9.23 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1998: llpo 9.26 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1999: llpo 9.28 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 8.54 lnc1 1.00 lnc1c1 0.00 lnc1c2 1.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1992: llpo 8.56 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1993: llpo 8.58 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1994: llpo 8.60 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1995: llpo 8.62 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.69 r4 0 r6 0 r7 0 conflict 0
# Year 1996: llpo 8.64 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.10 r4 0 r6 0 r7 0 conflict 0
# Year 1997: llpo 8.66 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.39 r4 0 r6 0 r7 0 conflict 0
# Year 1998: llpo 8.68 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
# Year 1999: llpo 8.70 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 10.92 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.57 r4 0 r6 0 r7 0 conflict 0
# Year 1992: llpo 10.94 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.61 r4 0 r6 0 r7 0 conflict 0
# Year 1993: llpo 10.96 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.66 r4 0 r6 0 r7 0 conflict 1
# Year 1994: llpo 10.98 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.85 r4 0 r6 0 r7 0 conflict 1
# Year 1995: llpo 10.99 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1996: llpo 11.01 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1997: llpo 11.03 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1998: llpo 11.05 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 1
# Year 1999: llpo 11.07 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 0 conflict 0
#
# Country ?
# Year 1991: llpo 8.01 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.80 r4 0 r6 0 r7 1 conflict 0
# Year 1992: llpo 8.04 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.87 r4 0 r6 0 r7 1 conflict 0
# Year 1993: llpo 8.06 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 6.93 r4 0 r6 0 r7 1 conflict 0
# Year 1994: llpo 8.09 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.50 r4 0 r6 0 r7 1 conflict 0
# Year 1995: llpo 8.12 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.53 r4 0 r6 0 r7 1 conflict 0
# Year 1996: llpo 8.15 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.11 r4 0 r6 0 r7 1 conflict 1
# Year 1997: llpo 8.17 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.17 r4 0 r6 0 r7 1 conflict 1
# Year 1998: llpo 8.20 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 0
# Year 1999: llpo 8.22 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 0
#
# Country ?
# Year 1991: llpo 12.12 lnc1 2.00 lnc1c1 2.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 1
# Year 1992: llpo 12.13 lnc1 2.00 lnc1c1 0.00 lnc1c2 2.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 1
# Year 1993: llpo 12.15 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 0
# Year 1994: llpo 12.16 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 0
# Year 1995: llpo 12.18 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 0
# Year 1996: llpo 12.19 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.69 r4 0 r6 0 r7 1 conflict 0
# Year 1997: llpo 12.21 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.10 r4 0 r6 0 r7 1 conflict 1
# Year 1998: llpo 12.22 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.39 r4 0 r6 0 r7 1 conflict 1
# Year 1999: llpo 12.24 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 0 r7 1 conflict 1
#
# Country ?
# Year 1991: llpo 11.92 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.57 r4 0 r6 0 r7 0 conflict 0
# Year 1992: llpo 11.93 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.61 r4 0 r6 0 r7 0 conflict 0
# Year 1993: llpo 11.95 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.66 r4 0 r6 0 r7 0 conflict 0
# Year 1994: llpo 11.96 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 7.70 r4 0 r6 0 r7 0 conflict 0
# Year 1995: llpo 11.98 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.87 r4 0 r6 0 r7 0 conflict 0
# Year 1996: llpo 11.99 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.89 r4 0 r6 0 r7 0 conflict 0
# Year 1997: llpo 12.01 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.91 r4 0 r6 0 r7 0 conflict 0
# Year 1998: llpo 12.02 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.93 r4 0 r6 0 r7 0 conflict 0
# Year 1999: llpo 12.04 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.95 r4 0 r6 0 r7 0 conflict 0
#
# Now, this is the history data for the country you are going to predict:
# Year 1991: llpo 7.67 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1992: llpo 7.65 lnc1 1.00 lnc1c1 0.00 lnc1c2 1.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 2
# Year 1993: llpo 7.64 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1994: llpo 7.63 lnc1 1.00 lnc1c1 0.00 lnc1c2 1.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1995: llpo 7.64 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 1
# Year 1996: llpo 7.67 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1997: llpo 7.73 lnc1 1.00 lnc1c1 1.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1998: llpo 7.81 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 0 r6 1 r7 0 conflict 0
# Year 1999: llpo 7.90 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 1.39 r4 0 r6 1 r7 0 conflict 0
#
# Carefully reason the relationship between the features and the conflict level, and then output:
# 1. Your reasoning in about 3-5 sentences
# 2. Your prediction with the format "Year [year]: [0/1/2]", for year from 2001 to 2019.
# 1. The data suggests that the conflict level in a country is influenced by a combination of factors including the previous neighborhood conflict (`lnc1`), whether the previous year had minor or major conflicts (`lnc1c1`, `lnc1c2`), and the population level (`llpo`). A pattern of decreasing conflict levels is observed when there's a consistent presence of neighborhood conflict (`lnc1`) but an increase in population (`llpo`). The transition from conflict to no conflict in the given country's data from 1996 onwards, despite an increase in `lnc1` in 1999, suggests that other factors like population growth and regional characteristics might play a stabilizing role.
#
# 2. Given the trend of stabilization in the later years (1996-1999) and considering the influence of population growth and regional characteristics, the prediction for the years 2001 to 2019 would cautiously assume a continuation of this trend, barring any drastic changes not reflected in the data. However, the slight increase in `lnc1` in 1999 could suggest a potential for conflict escalation, but without further data for the years 2000-2019, a conservative prediction would be:
#
# - Year 2001: 0
# - Year 2002: 0
# - Year 2003: 0
# - Year 2004: 0
# - Year 2005: 0
# - Year 2006: 0
# - Year 2007: 0
# - Year 2008: 0
# - Year 2009: 0
# - Year 2010: 0
# - Year 2011: 0
# - Year 2012: 0
# - Year 2013: 0
# - Year 2014: 0
# - Year 2015: 0
# - Year 2016: 0
# - Year 2017: 0
# - Year 2018: 0
# - Year 2019: 0
#
# This prediction assumes that the factors leading to the stabilization of conflict levels from 1996 to 1999 continue to play a significant role in the subsequent years.

# %% [markdown]
# #### Sweep over countries

# %%
country = 'Czech Republic'
get_example(country, 1991, 2000)    # missing 1991 and 1992 since does not exist yet
# Out:
# 'Year 1991: No data\nYear 1992: No data\nYear 1993: llpo nan lnc1 nan lnc1c1 nan lnc1c2 nan lnc1ts0 nan r4 1 r6 0 r7 0 conflict 0\nYear 1994: llpo 9.24 lnc1 2.00 lnc1c1 nan lnc1c2 nan lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0\nYear 1995: llpo 9.24 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0\nYear 1996: llpo 9.24 lnc1 1.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.69 r4 1 r6 0 r7 0 conflict 0\nYear 1997: llpo 9.24 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0\nYear 1998: llpo 9.24 lnc1 0.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 0.00 r4 1 r6 0 r7 0 conflict 0\nYear 1999: llpo 9.24 lnc1 2.00 lnc1c1 0.00 lnc1c2 0.00 lnc1ts0 3.22 r4 1 r6 0 r7 0 conflict 0\n'

# %%
num_example = 20
# his_start_year = 1991
# his_end_year = 2000
# pred_start_year = 2001
# pred_end_year = 2009
his_start_year = 1991
# his_start_year = 2000
his_end_year = 2009
pred_start_year = 2010
pred_end_year = 2018
use_cot = False
# country_pred_all = countries.tolist()[30:50]
country_pred_all = countries.tolist()
name = 'results'

results = {}
for country_pred in tqdm(country_pred_all):
    raw_preds = get_pred(country_pred, 
                     his_start_year, 
                     his_end_year, 
                     pred_start_year,
                     pred_end_year,
                     use_cot=use_cot,
                     num_example=num_example,
                     num_pred=1, 
                     pred_T=0)
    print(country_pred, raw_preds)
    preds = [extract_pred(raw_pred, 
                          pred_start_year, 
                          pred_end_year,) for raw_pred in raw_preds]
    print(country_pred, preds)
    results[country_pred] = preds

# save
with open(name + '.pkl', 'wb') as f:
    pickle.dump(results, f)
# Out:
#   0%|          | 0/172 [00:00<?, ?it/s]
# United States of America ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# United States of America [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Canada ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Canada [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Bahamas ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bahamas [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Cuba ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cuba [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Haiti ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Haiti [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Dominican Republic ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Dominican Republic [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Jamaica ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Jamaica [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Trinidad and Tobago ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Trinidad and Tobago [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Barbados ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Barbados [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Mexico ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Mexico [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Belize ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Belize [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Guatemala ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Guatemala [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Honduras ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Honduras [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# El Salvador ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# El Salvador [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Nicaragua ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Nicaragua [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Costa Rica ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Costa Rica [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Panama ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Panama [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Colombia ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Colombia [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Venezuela ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Venezuela [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Guyana ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Guyana [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Surinam ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Surinam [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Ecuador ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Ecuador [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Peru ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Peru [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Brazil ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Brazil [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Bolivia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bolivia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Paraguay ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Paraguay [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Chile ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Chile [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Argentina ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Argentina [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Uruguay ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Uruguay [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# United Kingdom ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# United Kingdom [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Ireland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Ireland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Netherlands ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Netherlands [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Belgium ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Belgium [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Luxembourg ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Luxembourg [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# France ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# France [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Switzerland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Switzerland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Spain ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Spain [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Portugal ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Portugal [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# German Federal Republic ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# German Federal Republic [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# German Democratic Republic ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# German Democratic Republic [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Poland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Poland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Austria ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Austria [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Hungary ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Hungary [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Czechoslovakia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Czechoslovakia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Czech Republic ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Czech Republic [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Slovakia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Slovakia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Italy/Sardinia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Italy/Sardinia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Malta ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Malta [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Albania ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Albania [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Macedonia (Former Yugoslav Republic of) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Macedonia (Former Yugoslav Republic of) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Croatia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Croatia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Yugoslavia (Serbia) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Yugoslavia (Serbia) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Bosnia-Herzegovina ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bosnia-Herzegovina [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Slovenia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Slovenia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Greece ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Greece [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Cyprus ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cyprus [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Bulgaria ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bulgaria [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Moldova ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Moldova [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Rumania ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Rumania [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Russia (Soviet Union) ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Russia (Soviet Union) [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Estonia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Estonia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Latvia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Latvia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Lithuania ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Lithuania [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Ukraine ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Ukraine [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Belarus (Byelorussia) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Belarus (Byelorussia) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Armenia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Armenia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Georgia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Georgia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Azerbaijan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Azerbaijan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Finland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Finland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Sweden ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Sweden [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Norway ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Norway [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Denmark ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Denmark [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Iceland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Iceland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Cape Verde ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cape Verde [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Guinea-Bissau ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Guinea-Bissau [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Equatorial Guinea ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Equatorial Guinea [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Gambia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Gambia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Mali ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 1\nYear 2014: 0\nYear 2015: 0\nYear 2016: 1\nYear 2017: 1\nYear 2018: 0']
# Mali [[0, 0, 0, 1, 0, 0, 1, 1, 0]]
# Senegal ['Year 2010: 0\nYear 2011: 1\nYear 2012: 1\nYear 2013: 0\nYear 2014: 1\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 1']
# Senegal [[0, 1, 1, 0, 1, 0, 0, 0, 1]]
# Benin ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Benin [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Mauritania ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Mauritania [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Niger ['Year 2010: 1\nYear 2011: 0\nYear 2012: 0\nYear 2013: 1\nYear 2014: 1\nYear 2015: 0\nYear 2016: 0\nYear 2017: 1\nYear 2018: 1']
# Niger [[1, 0, 0, 1, 1, 0, 0, 1, 1]]
# Cote DIvoire ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cote DIvoire [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Guinea ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Guinea [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Burkina Faso (Upper Volta) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Burkina Faso (Upper Volta) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Liberia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Liberia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Sierra Leone ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Sierra Leone [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Ghana ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Ghana [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Togo ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Togo [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Cameroon ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cameroon [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Nigeria ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Nigeria [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Gabon ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Gabon [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Central African Republic ['Year 2010: 1\nYear 2011: 0\nYear 2012: 0\nYear 2013: 1\nYear 2014: 1\nYear 2015: 0\nYear 2016: 0\nYear 2017: 1\nYear 2018: 0']
# Central African Republic [[1, 0, 0, 1, 1, 0, 0, 1, 0]]
# Chad ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 0\nYear 2014: 0\nYear 2015: 1\nYear 2016: 2\nYear 2017: 1\nYear 2018: 1']
# Chad [[1, 1, 1, 0, 0, 1, 2, 1, 1]]
# Congo ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Congo [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Congo, Democratic Republic of (Zaire) ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Congo, Democratic Republic of (Zaire) [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Uganda ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Uganda [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Kenya ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Kenya [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Tanzania/Tanganyika ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Tanzania/Tanganyika [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Burundi ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Burundi [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Rwanda ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 2\nYear 2018: 2']
# Rwanda [[0, 0, 0, 0, 1, 1, 1, 2, 2]]
# Somalia ['Year 2010: 1\nYear 2011: 1\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 1\nYear 2016: 2\nYear 2017: 1\nYear 2018: 0']
# Somalia [[1, 1, 0, 0, 0, 1, 2, 1, 0]]
# Djibouti ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Djibouti [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Ethiopia ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Ethiopia [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Eritrea ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Eritrea [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Angola ['Year 2010: 1\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 1\nYear 2015: 1\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Angola [[1, 0, 0, 0, 1, 1, 0, 0, 0]]
# Mozambique ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Mozambique [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Zambia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Zambia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Zimbabwe (Rhodesia) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Zimbabwe (Rhodesia) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Malawi ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Malawi [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# South Africa ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# South Africa [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Namibia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Namibia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Lesotho ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Lesotho [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Botswana ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Botswana [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Swaziland ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Swaziland [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Madagascar (Malagasy) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Madagascar (Malagasy) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Comoros ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Comoros [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Mauritius ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Mauritius [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Morocco ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Morocco [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Algeria ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Algeria [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Tunisia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Tunisia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Libya ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Libya [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Sudan ['Year 2010: 2\nYear 2011: 2\nYear 2012: 2\nYear 2013: 1\nYear 2014: 2\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Sudan [[2, 2, 2, 1, 2, 1, 1, 1, 1]]
# Iran (Persia) ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 0\nYear 2014: 0\nYear 2015: 1\nYear 2016: 1\nYear 2017: 0\nYear 2018: 1']
# Iran (Persia) [[1, 1, 1, 0, 0, 1, 1, 0, 1]]
# Turkey/Ottoman Empire ['Year 2010: 1\nYear 2011: 1\nYear 2012: 0\nYear 2013: 0\nYear 2014: 1\nYear 2015: 1\nYear 2016: 0\nYear 2017: 0\nYear 2018: 1']
# Turkey/Ottoman Empire [[1, 1, 0, 0, 1, 1, 0, 0, 1]]
# Iraq ['Year 2010: 2\nYear 2011: 1\nYear 2012: 1\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 1\nYear 2017: 2\nYear 2018: 2']
# Iraq [[2, 1, 1, 0, 0, 0, 1, 2, 2]]
# Egypt ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Egypt [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Syria ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Syria [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Lebanon ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Lebanon [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Jordan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Jordan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Israel ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Israel [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Saudi Arabia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Saudi Arabia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Yemen (Arab Republic of Yemen) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Yemen (Arab Republic of Yemen) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Kuwait ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Kuwait [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Bahrain ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bahrain [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Qatar ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Qatar [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# United Arab Emirates ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# United Arab Emirates [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Oman ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Oman [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Afghanistan ['Year 2010: 2\nYear 2011: 2\nYear 2012: 2\nYear 2013: 2\nYear 2014: 2\nYear 2015: 2\nYear 2016: 2\nYear 2017: 2\nYear 2018: 2']
# Afghanistan [[2, 2, 2, 2, 2, 2, 2, 2, 2]]
# Turkmenistan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Turkmenistan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Tajikistan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Tajikistan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Kyrgyz Republic ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Kyrgyz Republic [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Uzbekistan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 1\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Uzbekistan [[0, 0, 0, 0, 1, 0, 0, 0, 0]]
# Kazakhstan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Kazakhstan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# China ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# China [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Mongolia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Mongolia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Korea, People's Republic of ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Korea, People's Republic of [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Korea, Republic of ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Korea, Republic of [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Japan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Japan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# India ['Year 2010: 2\nYear 2011: 2\nYear 2012: 2\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# India [[2, 2, 2, 1, 1, 1, 1, 1, 1]]
# Bhutan ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bhutan [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Pakistan ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Pakistan [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Bangladesh ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Bangladesh [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Myanmar (Burma) ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Myanmar (Burma) [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Sri Lanka (Ceylon) ['Year 2010: 2\nYear 2011: 2\nYear 2012: 2\nYear 2013: 2\nYear 2014: 2\nYear 2015: 2\nYear 2016: 2\nYear 2017: 2\nYear 2018: 2']
# Sri Lanka (Ceylon) [[2, 2, 2, 2, 2, 2, 2, 2, 2]]
# Maldives ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Maldives [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Nepal ['Year 2010: 0\nYear 2011: 1\nYear 2012: 1\nYear 2013: 0\nYear 2014: 0\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 0']
# Nepal [[0, 1, 1, 0, 0, 1, 1, 1, 0]]
# Thailand ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Thailand [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Cambodia (Kampuchea) ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Cambodia (Kampuchea) [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Laos ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Laos [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Vietnam, Democratic Republic of ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Vietnam, Democratic Republic of [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Vietnam, Republic of ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Vietnam, Republic of [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Malaysia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Malaysia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Singapore ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Singapore [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Brunei ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Brunei [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Philippines ['Year 2010: 1\nYear 2011: 1\nYear 2012: 1\nYear 2013: 1\nYear 2014: 1\nYear 2015: 1\nYear 2016: 1\nYear 2017: 1\nYear 2018: 1']
# Philippines [[1, 1, 1, 1, 1, 1, 1, 1, 1]]
# Indonesia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Indonesia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Australia ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Australia [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Papua New Guinea ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Papua New Guinea [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# New Zealand ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# New Zealand [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Solomon Islands ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Solomon Islands [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
# Fiji ['Year 2010: 0\nYear 2011: 0\nYear 2012: 0\nYear 2013: 0\nYear 2014: 0\nYear 2015: 0\nYear 2016: 0\nYear 2017: 0\nYear 2018: 0']
# Fiji [[0, 0, 0, 0, 0, 0, 0, 0, 0]]

# %%
# save
with open(name + '.pkl', 'wb') as f:
    pickle.dump(results, f)

# %%
# combine results
results = {}
# paths = ['/home/allen/llm_civil_war_prediction/evaluation/results_cot_0-9.pkl', '/home/allen/llm_civil_war_prediction/evaluation/results_cot_10-29.pkl', '/home/allen/llm_civil_war_prediction/evaluation/results_cot_30-49.pkl']
paths = ['/home/allen/llm_civil_war_prediction/evaluation/results_all_1991-2009.pkl']
for path in paths:
    with open(path, 'rb') as f:
        results.update(pickle.load(f))
print('Total number of countries:', len(results))
# Out:
# Total number of countries: 172

# %% [markdown]
#  ### Compare with paper predictions

# %%
# paper_pred_path = "../data/Replication/CountryYearResults.dta"
# paper_pred_data = pd.read_stata(paper_pred_path)
# print(paper_pred_data)

# paper_pred_path = "/home/allen/llm_civil_war_prediction/data/Analysis/data/tables/predictions_2001_2009.csv"
paper_pred_path = "../data/Analysis/data/tables/predictions_2010_2050.csv"
paper_pred_data = pd.read_csv(paper_pred_path)
print(paper_pred_data)
# Out:
#       gwcode    year     minor     major  combined
# 0        2.0  2010.0  0.057222  0.005222  0.062444
# 1        2.0  2011.0  0.045000  0.007056  0.052056
# 2        2.0  2012.0  0.049056  0.016778  0.065833
# 3        2.0  2013.0  0.060222  0.016778  0.077000
# 4        2.0  2014.0  0.067611  0.018722  0.086333
# ...      ...     ...       ...       ...       ...
# 6924   950.0  2046.0  0.000278  0.000167  0.000444
# 6925   950.0  2047.0  0.000056  0.000000  0.000056
# 6926   950.0  2048.0  0.000222  0.000333  0.000556
# 6927   950.0  2049.0  0.000167  0.000000  0.000167
# 6928   950.0  2050.0  0.000000  0.000000  0.000000
#
# [6929 rows x 5 columns]

# %%
ft_data_path = "../data/Analysis/data/tables/acd.csv"
ft_data = pd.read_csv(ft_data_path)
# country_code = country_codes[country_pred]
# print(ft_data)
# print(country_code.columns)
# print(actual_data[actual_data["gwcode"] == country_code])
# actual_data_country = actual_data[actual_data["gwcode"] == country_code & (actual_data["year"] >= pred_start_year) & (actual_data["year"] <= pred_end_year)]

# # if the year is missing, add it with conflict 0
# for i in range(pred_start_year, pred_end_year+1):
#     if i not in actual_data_country["year"].tolist():
#         # add to dataframe
#         actual_data_country = pd.concat([actual_data_country, 
#                                 pd.DataFrame([[country_code, i, 0, 0, 0, 0]], 
#                                 columns=actual_data_country.columns)], 
#                                 ignore_index=True)

# %%
# paper_pred_threshold = 0.5
# paper_pred_threshold_all = np.arange(0.01, 1.00, 0.03)
paper_pred_threshold_all = [0.5]
pred_start_year = 2010
pred_end_year = 2018

llm_true_positive_rate = []
llm_false_positive_rate = []
# paper_true_positive_rate = []
# paper_false_positive_rate = []
for paper_pred_threshold in tqdm(paper_pred_threshold_all): # very inefficient
    paper_success = []
    llm_success = []
    TP = 0
    FP = 0
    TN = 0
    FN = 0
    TP_paper = 0
    FP_paper = 0
    TN_paper = 0
    FN_paper = 0
    for country, preds in results.items():
        country_code = country_codes[country]

        # get ground truth
        ft_country = ft_data[(ft_data["gwcode"] == country_code) & (ft_data["year"] >= pred_start_year) & (ft_data["year"] <= pred_end_year)]
        for year in range(pred_start_year, pred_end_year+1): # if the year is missing, add it with conflict 0
            if year not in ft_country["year"].tolist():
                # add to dataframe
                ft_country = pd.concat([ft_country, 
                                pd.DataFrame([[year, country_code, 0, 0, 0, 0]], 
                                columns=ft_country.columns)], 
                                ignore_index=True)
        # print(ft_country)

        # get paper prediction
        paper_pred_country = paper_pred_data[paper_pred_data["gwcode"] == country_code]
        preds = preds[0]    #! no ensembling, so each preds have only one set of prediction
        for year in range(pred_start_year, pred_end_year+1):
            
            # get ground truth
            assert ft_country[ft_country["year"] == year].minor_actual.values[0] + ft_country[ft_country["year"] == year].major_actual.values[0] < 2, "Cannot be both minor and major conflict at the same time."
            if ft_country[ft_country["year"] == year].minor_actual.values[0] > 0:
                ft = 1
            elif ft_country[ft_country["year"] == year].major_actual.values[0] > 0:
                ft = 2
            else:
                ft = 0

            # get llm prediction
            llm_pred = preds[year-pred_start_year]

            # get the paper prediction
            try:
                if paper_pred_country[paper_pred_country["year"] == year].major.values[0] > paper_pred_threshold:
                    paper_pred = 1
                elif paper_pred_country[paper_pred_country["year"] == year].minor.values[0] > paper_pred_threshold:
                    paper_pred = 2
                else:
                    paper_pred = 0

                # compare - only consider if there is a conflict
                # print(ft, llm_pred, paper_pred)
                # llm_success.append(ft == llm_pred)
                # paper_success.append(ft == paper_pred)
                llm_success.append((ft > 0 and llm_pred > 0) or (ft == 0 and llm_pred == 0))
                paper_success.append((ft > 0 and paper_pred > 0) or (ft == 0 and paper_pred == 0))

                # true positive, false positive, true negative, false negative
                if ft > 0:
                    if llm_pred > 0:
                        TP += 1
                    else:
                        FN += 1
                    if paper_pred > 0:
                        TP_paper += 1
                    else:
                        FN_paper += 1
                else:
                    if llm_pred == 0:
                        TN += 1
                    else:
                        FP += 1
                    if paper_pred == 0:
                        TN_paper += 1
                    else:
                        FP_paper += 1
                
            except:
                # print('No paper prediction for', country, year)
                pass

    print('Incidence of conflict:')
    print('LLM accuracy:', np.mean(llm_success))
    # print('Paper accuracy:', np.mean(paper_success))
    print('LLM True positive:', TP)
    print('LLM False positive:', FP)
    print('LLM True negative:', TN)
    print('LLM False negative:', FN)
    print('LLM Precision:', TP/(TP+FP))
    print('LLM Recall:', TP/(TP+FN))
    # print('Paper True positive:', TP_paper)
    # print('Paper False positive:', FP_paper)
    # print('Paper True negative:', TN_paper)
    # print('Paper False negative:', FN_paper)
    # print('Paper Precision:', TP_paper/(TP_paper+FP_paper))
    # print('Paper Recall:', TP_paper/(TP_paper+FN_paper))
    
    llm_true_positive_rate = TP/(TP+FN)
    llm_false_positive_rate = FP/(FP+TN)
#     paper_true_positive_rate.append(TP_paper/(TP_paper+FN_paper))
#     paper_false_positive_rate.append(FP_paper/(FP_paper+TN_paper))
# print(llm_true_positive_rate, llm_false_positive_rate, paper_true_positive_rate, paper_false_positive_rate)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Incidence of conflict:
# LLM accuracy: 0.8888888888888888
# LLM True positive: 152
# LLM False positive: 60
# LLM True negative: 1200
# LLM False negative: 109
# LLM Precision: 0.7169811320754716
# LLM Recall: 0.5823754789272031

# %%
no_cot_91_09 = [
    llm_true_positive_rate, llm_false_positive_rate
]

# %%
cot_91_09 = [
    llm_true_positive_rate, llm_false_positive_rate
]

# %%
cot_00_09 = [
    llm_true_positive_rate, llm_false_positive_rate
]

# %%
# plot ROC curve
# plt.scatter(llm_false_positive_rate, llm_true_positive_rate, label='gpt-4-0125-preview', color='red')
plt.scatter(cot_91_09[1], cot_91_09[0], label='LLM, CoT, 1991-2009', color='red')
plt.scatter(cot_00_09[1], cot_00_09[0], label='LLM, CoT, 2000-2009', color='green')
plt.scatter(no_cot_91_09[1], no_cot_91_09[0], label='LLM, No CoT, 1991-2009', color='blue')
plt.plot(paper_false_positive_rate, paper_true_positive_rate, '-o', label='Hegre et al.', color='black')
plt.plot([0, 1], [0, 1], '--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### TODO: get LLM probs with ensemble, and compare AUROC

# %%
# example of predictions
llm_pred_data_path = 'results_cot_all_1991-2009.pkl'
with open(llm_pred_data_path, 'rb') as f:
    llm_pre_data = pickle.load(f)
print(llm_pre_data['Mexico'])
# Out:
# [[0, 0, 0, 0, 0, 0, 0, 0, 0]]
